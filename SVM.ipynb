# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import SVC 
from sklearn.metrics import accuracy_score,classification_report 
df=pd.read_csv(r"C:\Users\rohit\Downloads\cats_vs_dogs.csv") 
print(df.head())  
df = df.drop(columns=["Unnamed: 0"])
x= df.drop(columns=["label"]) 
y= df["label"] 

x=pd.get_dummies(x,columns=['state'])
X_train,X_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42) 
scaler= StandardScaler() 
X_train=scaler.fit_transform(X_train) 
X_test= scaler.transform(X_test) 
svm_model=SVC(kernel="rbf",C=1.0,gamma="scale",random_state=42) 
svm_model.fit(X_train,y_train) 
y_pred= svm_model.predict(X_test) 
accuracy= accuracy_score(y_test,y_pred) 
classification= classification_report(y_test,y_pred) 
print("Accuracy:",accuracy*100) 
print("Classification Report:",classification)
# Out:
#    Unnamed: 0       state  n_households  percent_pet_households  \
# 0         NaN     Alabama          1828                    59.5
# 1         NaN     Arizona          2515                    59.5
# 2         NaN    Arkansas          1148                    62.4
# 3         NaN  California         12974                    52.9
# 4         NaN    Colorado          1986                    61.3
#
#    n_pet_households  percent_dog_owners  n_dog_households  \
# 0              1088                44.1               807
# 1              1497                40.1              1008
# 2               716                47.9               550
# 3              6865                32.8              4260
# 4              1217                42.5               845
#
#    avg_dogs_per_household  dog_population  percent_cat_owners  \
# 0                     1.7            1410                27.4
# 1                     1.8            1798                29.6
# 2                     2.0            1097                30.6
# 3                     1.6            6687                28.3
# 4                     1.6            1349                32.3
#
#    n_cat_households  avg_cats_per_household  cat_population  dog_cat_ratio  \
# 0               501                     2.5            1252       1.125299
# 1               743                     1.9            1438       1.249479
# 2               351                     2.3             810       1.352651
# 3              3687                     1.9            7118       0.939317
# 4               642                     1.9            1191       1.131711
#
#   label
# 0   dog
# 1   dog
# 2   dog
# 3   cat
# 4   dog
# Accuracy: 90.0
# Classification Report:               precision    recall  f1-score   support
#
#          cat       1.00      0.89      0.94         9
#          dog       0.50      1.00      0.67         1
#
#     accuracy                           0.90        10
#    macro avg       0.75      0.94      0.80        10
# weighted avg       0.95      0.90      0.91        10
